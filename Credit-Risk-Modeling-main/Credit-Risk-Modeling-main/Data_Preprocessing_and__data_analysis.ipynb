# %%
import numpy as np
import pandas as pd
import seaborn as sns
import glob
import matplotlib.pyplot as plt
from zipfile import ZipFile
import warnings

# %%
from google.colab import drive
drive.mount("/content/drive/" , force_remount = True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# #Loading Dataset

# %%
file_name1 = '/content/drive/MyDrive/Self_Project/loan_data_2007_2014.csv.zip'
with ZipFile(file_name1,'r') as zip:
  zip.extractall("/content/data1")
  print('Extracted files at location /content/data1 ')
# Out:
# Extracted files at location /content/data1

# %% [markdown]
# $\text{Below alternative can be used in google colab for unzipping}$

# %%
#!unzip '/content/drive/MyDrive/Self_Project/loan_data_2007_2014.csv.zip' -d "/content/data1"

# %%
data = pd.read_csv("/content/data1/loan_data_2007_2014.csv" , low_memory = False , index_col = None)

# %% [markdown]
# #Data Visualization and Pre-Processing

# %%
data.head()
# Out:
#    Unnamed: 0       id  member_id  ...  inq_fi  total_cu_tl  inq_last_12m
# 0           0  1077501    1296599  ...     NaN          NaN           NaN
# 1           1  1077430    1314167  ...     NaN          NaN           NaN
# 2           2  1077175    1313524  ...     NaN          NaN           NaN
# 3           3  1076863    1277178  ...     NaN          NaN           NaN
# 4           4  1075358    1311748  ...     NaN          NaN           NaN
#
# [5 rows x 75 columns]

# %%
print("Shape of the dataset " , data.shape)
print("No. of rows/Customers in the dataset =" , data.shape[0])
print("No. of columns in the dataset =" , data.shape[1])
# Out:
# Shape of the dataset  (466285, 75)
# No. of rows/Customers in the dataset = 466285
# No. of columns in the dataset = 75

# %% [markdown]
# $\text{Checking datatypes of columns}$

# %%
float = 0
int = 0
object = 0
for col in data.columns :
  if data[col].dtype == "float64" :
    float +=1
  elif data[col].dtype == "int64" :
    int += 1
  elif data[col].dtype == "object" :
    object += 1
print(f"Total columns having float64 as datatype= {float} \nTotal columns having int64 as datatype = {int} \nTotal columns having object datatype = {object}")
# Out:
# Total columns having float64 as datatype= 46
# Total columns having int64 as datatype = 7
# Total columns having object datatype = 22

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 75 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   466285 non-null  int64
#  1   id                           466285 non-null  int64
#  2   member_id                    466285 non-null  int64
#  3   loan_amnt                    466285 non-null  int64
#  4   funded_amnt                  466285 non-null  int64
#  5   funded_amnt_inv              466285 non-null  float64
#  6   term                         466285 non-null  object
#  7   int_rate                     466285 non-null  float64
#  8   installment                  466285 non-null  float64
#  9   grade                        466285 non-null  object
#  10  sub_grade                    466285 non-null  object
#  11  emp_title                    438697 non-null  object
#  12  emp_length                   445277 non-null  object
#  13  home_ownership               466285 non-null  object
#  14  annual_inc                   466281 non-null  float64
#  15  verification_status          466285 non-null  object
#  16  issue_d                      466285 non-null  object
#  17  loan_status                  466285 non-null  object
#  18  pymnt_plan                   466285 non-null  object
#  19  url                          466285 non-null  object
#  20  desc                         125983 non-null  object
#  21  purpose                      466285 non-null  object
#  22  title                        466265 non-null  object
#  23  zip_code                     466285 non-null  object
#  24  addr_state                   466285 non-null  object
#  25  dti                          466285 non-null  float64
#  26  delinq_2yrs                  466256 non-null  float64
#  27  earliest_cr_line             466256 non-null  object
#  28  inq_last_6mths               466256 non-null  float64
#  29  mths_since_last_delinq       215934 non-null  float64
#  30  mths_since_last_record       62638 non-null   float64
#  31  open_acc                     466256 non-null  float64
#  32  pub_rec                      466256 non-null  float64
#  33  revol_bal                    466285 non-null  int64
#  34  revol_util                   465945 non-null  float64
#  35  total_acc                    466256 non-null  float64
#  36  initial_list_status          466285 non-null  object
#  37  out_prncp                    466285 non-null  float64
#  38  out_prncp_inv                466285 non-null  float64
#  39  total_pymnt                  466285 non-null  float64
#  40  total_pymnt_inv              466285 non-null  float64
#  41  total_rec_prncp              466285 non-null  float64
#  42  total_rec_int                466285 non-null  float64
#  43  total_rec_late_fee           466285 non-null  float64
#  44  recoveries                   466285 non-null  float64
#  45  collection_recovery_fee      466285 non-null  float64
#  46  last_pymnt_d                 465909 non-null  object
#  47  last_pymnt_amnt              466285 non-null  float64
#  48  next_pymnt_d                 239071 non-null  object
#  49  last_credit_pull_d           466243 non-null  object
#  50  collections_12_mths_ex_med   466140 non-null  float64
#  51  mths_since_last_major_derog  98974 non-null   float64
#  52  policy_code                  466285 non-null  int64
#  53  application_type             466285 non-null  object
#  54  annual_inc_joint             0 non-null       float64
#  55  dti_joint                    0 non-null       float64
#  56  verification_status_joint    0 non-null       float64
#  57  acc_now_delinq               466256 non-null  float64
#  58  tot_coll_amt                 396009 non-null  float64
#  59  tot_cur_bal                  396009 non-null  float64
#  60  open_acc_6m                  0 non-null       float64
#  61  open_il_6m                   0 non-null       float64
#  62  open_il_12m                  0 non-null       float64
#  63  open_il_24m                  0 non-null       float64
#  64  mths_since_rcnt_il           0 non-null       float64
#  65  total_bal_il                 0 non-null       float64
#  66  il_util                      0 non-null       float64
#  67  open_rv_12m                  0 non-null       float64
#  68  open_rv_24m                  0 non-null       float64
#  69  max_bal_bc                   0 non-null       float64
#  70  all_util                     0 non-null       float64
#  71  total_rev_hi_lim             396009 non-null  float64
#  72  inq_fi                       0 non-null       float64
#  73  total_cu_tl                  0 non-null       float64
#  74  inq_last_12m                 0 non-null       float64
# dtypes: float64(46), int64(7), object(22)
# memory usage: 266.8+ MB

# %% [markdown]
# $\text{There are 75 columns in the dataset.The columns contain 3 types of datatypes like float (discrete numerical) , int (integer) and object (categorical)}$.

# %%
count = 0
missing = []
for col in data.columns :
  p = data[col].isna().mean()
  if p > 0.75 :
    missing.append(col)
    count += 1
    continue
print("Total columns with more than 75% missing values are =",count)
print("Those columns are : ",missing)
# Out:
# Total columns with more than 75% missing values are = 19
# Those columns are :  ['mths_since_last_record', 'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'open_acc_6m', 'open_il_6m', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'inq_fi', 'total_cu_tl', 'inq_last_12m']

# %% [markdown]
# $\text{We have 19 columns with more than 75% null values. We might remove them later after further analysis.}$

# %%
data.describe()
# Out:
#           Unnamed: 0            id  ...  total_cu_tl  inq_last_12m
# count  466285.000000  4.662850e+05  ...          0.0           0.0
# mean   233142.000000  1.307973e+07  ...          NaN           NaN
# std    134605.029472  1.089371e+07  ...          NaN           NaN
# min         0.000000  5.473400e+04  ...          NaN           NaN
# 25%    116571.000000  3.639987e+06  ...          NaN           NaN
# 50%    233142.000000  1.010790e+07  ...          NaN           NaN
# 75%    349713.000000  2.073121e+07  ...          NaN           NaN
# max    466284.000000  3.809811e+07  ...          NaN           NaN
#
# [8 rows x 53 columns]

# %% [markdown]
# $\text{Detailed information of columns data}$

# %%
for col in data.columns.values :
  values = pd.unique(data[col])
  print("\033[1m" + col + "\033[0m" + " is of type " + "\033[1m"+str(data[col].dtypes) + "\033[0m" + " and has " + "\033[1m"+ str(len(values)) + "\033[0m" + " unique values " + "and " + "\033[1m" +str(data[col].isna().sum()) + "\033[0m" + " null values")
  if len(values) < 20 :
    lst = ''
    for i in range(0 , len(values)) :
      lst = lst + str(values[i]) + ' ,'
    print("These are : " , lst[0:len(lst)-2])
# Out:
# Unnamed: 0 is of type int64 and has 466285 unique values and 0 null values
# id is of type int64 and has 466285 unique values and 0 null values
# member_id is of type int64 and has 466285 unique values and 0 null values
# loan_amnt is of type int64 and has 1352 unique values and 0 null values
# funded_amnt is of type int64 and has 1354 unique values and 0 null values
# funded_amnt_inv is of type float64 and has 9854 unique values and 0 null values
# term is of type object and has 2 unique values and 0 null values
# These are :   36 months , 60 months
# int_rate is of type float64 and has 506 unique values and 0 null values
# installment is of type float64 and has 55622 unique values and 0 null values
# grade is of type object and has 7 unique values and 0 null values
# These are :  B ,C ,A ,E ,F ,D ,G
# sub_grade is of type object and has 35 unique values and 0 null values
# emp_title is of type object and has 205476 unique values and 27588 null values
# emp_length is of type object and has 12 unique values and 21008 null values
# These are :  10+ years ,< 1 year ,1 year ,3 years ,8 years ,9 years ,4 years ,5 years ,6 years ,2 years ,7 years ,nan
# home_ownership is of type object and has 6 unique values and 0 null values
# These are :  RENT ,OWN ,MORTGAGE ,OTHER ,NONE ,ANY
# annual_inc is of type float64 and has 31902 unique values and 4 null values
# verification_status is of type object and has 3 unique values and 0 null values
# These are :  Verified ,Source Verified ,Not Verified
# issue_d is of type object and has 91 unique values and 0 null values
# loan_status is of type object and has 9 unique values and 0 null values
# These are :  Fully Paid ,Charged Off ,Current ,Default ,Late (31-120 days) ,In Grace Period ,Late (16-30 days) ,Does not meet the credit policy. Status:Fully Paid ,Does not meet the credit policy. Status:Charged Off
# pymnt_plan is of type object and has 2 unique values and 0 null values
# These are :  n ,y
# url is of type object and has 466285 unique values and 0 null values
# desc is of type object and has 124437 unique values and 340302 null values
# purpose is of type object and has 14 unique values and 0 null values
# These are :  credit_card ,car ,small_business ,other ,wedding ,debt_consolidation ,home_improvement ,major_purchase ,medical ,moving ,vacation ,house ,renewable_energy ,educational
# title is of type object and has 63100 unique values and 20 null values
# zip_code is of type object and has 888 unique values and 0 null values
# addr_state is of type object and has 50 unique values and 0 null values
# dti is of type float64 and has 3997 unique values and 0 null values
# delinq_2yrs is of type float64 and has 25 unique values and 29 null values
# earliest_cr_line is of type object and has 665 unique values and 29 null values
# inq_last_6mths is of type float64 and has 29 unique values and 29 null values
# mths_since_last_delinq is of type float64 and has 146 unique values and 250351 null values
# mths_since_last_record is of type float64 and has 124 unique values and 403647 null values
# open_acc is of type float64 and has 63 unique values and 29 null values
# pub_rec is of type float64 and has 27 unique values and 29 null values
# revol_bal is of type int64 and has 58142 unique values and 0 null values
# revol_util is of type float64 and has 1270 unique values and 340 null values
# total_acc is of type float64 and has 113 unique values and 29 null values
# initial_list_status is of type object and has 2 unique values and 0 null values
# These are :  f ,w
# out_prncp is of type float64 and has 135665 unique values and 0 null values
# out_prncp_inv is of type float64 and has 141189 unique values and 0 null values
# total_pymnt is of type float64 and has 351609 unique values and 0 null values
# total_pymnt_inv is of type float64 and has 347659 unique values and 0 null values
# total_rec_prncp is of type float64 and has 172713 unique values and 0 null values
# total_rec_int is of type float64 and has 270249 unique values and 0 null values
# total_rec_late_fee is of type float64 and has 5808 unique values and 0 null values
# recoveries is of type float64 and has 22773 unique values and 0 null values
# collection_recovery_fee is of type float64 and has 20275 unique values and 0 null values
# last_pymnt_d is of type object and has 99 unique values and 376 null values
# last_pymnt_amnt is of type float64 and has 198194 unique values and 0 null values
# next_pymnt_d is of type object and has 101 unique values and 227214 null values
# last_credit_pull_d is of type object and has 104 unique values and 42 null values
# collections_12_mths_ex_med is of type float64 and has 10 unique values and 145 null values
# These are :  0.0 ,nan ,1.0 ,2.0 ,4.0 ,3.0 ,6.0 ,16.0 ,20.0 ,5.0
# mths_since_last_major_derog is of type float64 and has 163 unique values and 367311 null values
# policy_code is of type int64 and has 1 unique values and 0 null values
# These are :  1
# application_type is of type object and has 1 unique values and 0 null values
# These are :  INDIVIDUAL
# annual_inc_joint is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# dti_joint is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# verification_status_joint is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# acc_now_delinq is of type float64 and has 7 unique values and 29 null values
# These are :  0.0 ,1.0 ,nan ,2.0 ,3.0 ,5.0 ,4.0
# tot_coll_amt is of type float64 and has 6322 unique values and 70276 null values
# tot_cur_bal is of type float64 and has 220691 unique values and 70276 null values
# open_acc_6m is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# open_il_6m is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# open_il_12m is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# open_il_24m is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# mths_since_rcnt_il is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# total_bal_il is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# il_util is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# open_rv_12m is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# open_rv_24m is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# max_bal_bc is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# all_util is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# total_rev_hi_lim is of type float64 and has 14613 unique values and 70276 null values
# inq_fi is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# total_cu_tl is of type float64 and has 1 unique values and 466285 null values
# These are :  nan
# inq_last_12m is of type float64 and has 1 unique values and 466285 null values
# These are :  nan

# %% [markdown]
# $\text{Droping columns with more than 80% null values.}$

# %%
new_data = data.dropna(axis = 1 , how = "all" , thresh = data.shape[0]*0.25)
pd.options.mode.chained_assignment = None
new_data.drop('Unnamed: 0' ,inplace = True , axis = 1)

# %%
new_data.head(3)
# Out:
#         id  member_id  loan_amnt  ...  tot_coll_amt  tot_cur_bal total_rev_hi_lim
# 0  1077501    1296599       5000  ...           NaN          NaN              NaN
# 1  1077430    1314167       2500  ...           NaN          NaN              NaN
# 2  1077175    1313524       2400  ...           NaN          NaN              NaN
#
# [3 rows x 55 columns]

# %%
print("Shape of the new data after handling missing value columns : " , new_data.shape)
# Out:
# Shape of the new data after handling missing value columns :  (466285, 55)

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 55 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   id                          466285 non-null  int64
#  1   member_id                   466285 non-null  int64
#  2   loan_amnt                   466285 non-null  int64
#  3   funded_amnt                 466285 non-null  int64
#  4   funded_amnt_inv             466285 non-null  float64
#  5   term                        466285 non-null  object
#  6   int_rate                    466285 non-null  float64
#  7   installment                 466285 non-null  float64
#  8   grade                       466285 non-null  object
#  9   sub_grade                   466285 non-null  object
#  10  emp_title                   438697 non-null  object
#  11  emp_length                  445277 non-null  object
#  12  home_ownership              466285 non-null  object
#  13  annual_inc                  466281 non-null  float64
#  14  verification_status         466285 non-null  object
#  15  issue_d                     466285 non-null  object
#  16  loan_status                 466285 non-null  object
#  17  pymnt_plan                  466285 non-null  object
#  18  url                         466285 non-null  object
#  19  desc                        125983 non-null  object
#  20  purpose                     466285 non-null  object
#  21  title                       466265 non-null  object
#  22  zip_code                    466285 non-null  object
#  23  addr_state                  466285 non-null  object
#  24  dti                         466285 non-null  float64
#  25  delinq_2yrs                 466256 non-null  float64
#  26  earliest_cr_line            466256 non-null  object
#  27  inq_last_6mths              466256 non-null  float64
#  28  mths_since_last_delinq      215934 non-null  float64
#  29  open_acc                    466256 non-null  float64
#  30  pub_rec                     466256 non-null  float64
#  31  revol_bal                   466285 non-null  int64
#  32  revol_util                  465945 non-null  float64
#  33  total_acc                   466256 non-null  float64
#  34  initial_list_status         466285 non-null  object
#  35  out_prncp                   466285 non-null  float64
#  36  out_prncp_inv               466285 non-null  float64
#  37  total_pymnt                 466285 non-null  float64
#  38  total_pymnt_inv             466285 non-null  float64
#  39  total_rec_prncp             466285 non-null  float64
#  40  total_rec_int               466285 non-null  float64
#  41  total_rec_late_fee          466285 non-null  float64
#  42  recoveries                  466285 non-null  float64
#  43  collection_recovery_fee     466285 non-null  float64
#  44  last_pymnt_d                465909 non-null  object
#  45  last_pymnt_amnt             466285 non-null  float64
#  46  next_pymnt_d                239071 non-null  object
#  47  last_credit_pull_d          466243 non-null  object
#  48  collections_12_mths_ex_med  466140 non-null  float64
#  49  policy_code                 466285 non-null  int64
#  50  application_type            466285 non-null  object
#  51  acc_now_delinq              466256 non-null  float64
#  52  tot_coll_amt                396009 non-null  float64
#  53  tot_cur_bal                 396009 non-null  float64
#  54  total_rev_hi_lim            396009 non-null  float64
# dtypes: float64(27), int64(6), object(22)
# memory usage: 195.7+ MB

# %%
for col in new_data.columns.values :
  values = pd.unique(new_data[col])
  print("\033[1m" + col + "\033[0m" + " is of type " + "\033[1m"+str(new_data[col].dtypes) + "\033[0m" + " and has " + "\033[1m"+ str(len(values)) + "\033[0m" + " unique values " + "and " + "\033[1m" +str(new_data[col].isna().sum()) + "\033[0m" + " null values")
  if len(values) < 20 :
    lst = ''
    for i in range(0 , len(values)) :
      lst = lst + str(values[i]) + ' ,'
    print("These are : " , lst[0:len(lst)-2])
# Out:
# id is of type int64 and has 466285 unique values and 0 null values
# member_id is of type int64 and has 466285 unique values and 0 null values
# loan_amnt is of type int64 and has 1352 unique values and 0 null values
# funded_amnt is of type int64 and has 1354 unique values and 0 null values
# funded_amnt_inv is of type float64 and has 9854 unique values and 0 null values
# term is of type object and has 2 unique values and 0 null values
# These are :   36 months , 60 months
# int_rate is of type float64 and has 506 unique values and 0 null values
# installment is of type float64 and has 55622 unique values and 0 null values
# grade is of type object and has 7 unique values and 0 null values
# These are :  B ,C ,A ,E ,F ,D ,G
# sub_grade is of type object and has 35 unique values and 0 null values
# emp_title is of type object and has 205476 unique values and 27588 null values
# emp_length is of type object and has 12 unique values and 21008 null values
# These are :  10+ years ,< 1 year ,1 year ,3 years ,8 years ,9 years ,4 years ,5 years ,6 years ,2 years ,7 years ,nan
# home_ownership is of type object and has 6 unique values and 0 null values
# These are :  RENT ,OWN ,MORTGAGE ,OTHER ,NONE ,ANY
# annual_inc is of type float64 and has 31902 unique values and 4 null values
# verification_status is of type object and has 3 unique values and 0 null values
# These are :  Verified ,Source Verified ,Not Verified
# issue_d is of type object and has 91 unique values and 0 null values
# loan_status is of type object and has 9 unique values and 0 null values
# These are :  Fully Paid ,Charged Off ,Current ,Default ,Late (31-120 days) ,In Grace Period ,Late (16-30 days) ,Does not meet the credit policy. Status:Fully Paid ,Does not meet the credit policy. Status:Charged Off
# pymnt_plan is of type object and has 2 unique values and 0 null values
# These are :  n ,y
# url is of type object and has 466285 unique values and 0 null values
# desc is of type object and has 124437 unique values and 340302 null values
# purpose is of type object and has 14 unique values and 0 null values
# These are :  credit_card ,car ,small_business ,other ,wedding ,debt_consolidation ,home_improvement ,major_purchase ,medical ,moving ,vacation ,house ,renewable_energy ,educational
# title is of type object and has 63100 unique values and 20 null values
# zip_code is of type object and has 888 unique values and 0 null values
# addr_state is of type object and has 50 unique values and 0 null values
# dti is of type float64 and has 3997 unique values and 0 null values
# delinq_2yrs is of type float64 and has 25 unique values and 29 null values
# earliest_cr_line is of type object and has 665 unique values and 29 null values
# inq_last_6mths is of type float64 and has 29 unique values and 29 null values
# mths_since_last_delinq is of type float64 and has 146 unique values and 250351 null values
# open_acc is of type float64 and has 63 unique values and 29 null values
# pub_rec is of type float64 and has 27 unique values and 29 null values
# revol_bal is of type int64 and has 58142 unique values and 0 null values
# revol_util is of type float64 and has 1270 unique values and 340 null values
# total_acc is of type float64 and has 113 unique values and 29 null values
# initial_list_status is of type object and has 2 unique values and 0 null values
# These are :  f ,w
# out_prncp is of type float64 and has 135665 unique values and 0 null values
# out_prncp_inv is of type float64 and has 141189 unique values and 0 null values
# total_pymnt is of type float64 and has 351609 unique values and 0 null values
# total_pymnt_inv is of type float64 and has 347659 unique values and 0 null values
# total_rec_prncp is of type float64 and has 172713 unique values and 0 null values
# total_rec_int is of type float64 and has 270249 unique values and 0 null values
# total_rec_late_fee is of type float64 and has 5808 unique values and 0 null values
# recoveries is of type float64 and has 22773 unique values and 0 null values
# collection_recovery_fee is of type float64 and has 20275 unique values and 0 null values
# last_pymnt_d is of type object and has 99 unique values and 376 null values
# last_pymnt_amnt is of type float64 and has 198194 unique values and 0 null values
# next_pymnt_d is of type object and has 101 unique values and 227214 null values
# last_credit_pull_d is of type object and has 104 unique values and 42 null values
# collections_12_mths_ex_med is of type float64 and has 10 unique values and 145 null values
# These are :  0.0 ,nan ,1.0 ,2.0 ,4.0 ,3.0 ,6.0 ,16.0 ,20.0 ,5.0
# policy_code is of type int64 and has 1 unique values and 0 null values
# These are :  1
# application_type is of type object and has 1 unique values and 0 null values
# These are :  INDIVIDUAL
# acc_now_delinq is of type float64 and has 7 unique values and 29 null values
# These are :  0.0 ,1.0 ,nan ,2.0 ,3.0 ,5.0 ,4.0
# tot_coll_amt is of type float64 and has 6322 unique values and 70276 null values
# tot_cur_bal is of type float64 and has 220691 unique values and 70276 null values
# total_rev_hi_lim is of type float64 and has 14613 unique values and 70276 null values

# %%
for col in new_data.columns.values :
  if (new_data[col].dtype == "int64")  | (new_data[col].dtype == "float64" ) :
    plt.hist(new_data[col])
    plt.xlabel(col)
    plt.show()

# %%
for col in new_data.columns.values :
  try:
    if (new_data[col].dtype == "object") :
      plt.hist(new_data[col])
      plt.xlabel(col)
      plt.show()
  except :
    continue

# %% [markdown]
# $\text{Dropping columns which are not much informative with respect to our prediction or which have very less variations in them or does not have much good spread in distribution.}$

# %%
new_data.head()
# Out:
#         id  member_id  loan_amnt  ...  tot_coll_amt  tot_cur_bal total_rev_hi_lim
# 0  1077501    1296599       5000  ...           NaN          NaN              NaN
# 1  1077430    1314167       2500  ...           NaN          NaN              NaN
# 2  1077175    1313524       2400  ...           NaN          NaN              NaN
# 3  1076863    1277178      10000  ...           NaN          NaN              NaN
# 4  1075358    1311748       3000  ...           NaN          NaN              NaN
#
# [5 rows x 55 columns]

# %%
new_data.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'policy_code', 'application_type',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim'],
#       dtype='object')

# %% [markdown]
# Removing columns that have :
#
# 1. 19 features with more than 75% of missing values.Any technique to impute them will result in inaccurate results
#
# 2. Certain static features not related to credit risk, e.g., id, member_id, url, title
# 3. Other forward-looking features that are expected to be populated only once the borrower has defaulted, e.g., recoveries, collection_recovery_fee

# %%
new_data.drop(columns = ['id', 'member_id', 'sub_grade', 'emp_title', 'url', 'desc', 'title', 'zip_code', 'next_pymnt_d','recoveries', 'collection_recovery_fee', 'total_rec_prncp', 'total_rec_late_fee'  , 'application_type'] , inplace=True)

# %%
print("The shape of data after dropping unnecessary columns : " , new_data.shape)
# Out:
# The shape of data after dropping unnecessary columns :  (466285, 41)

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 41 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   466285 non-null  int64
#  1   funded_amnt                 466285 non-null  int64
#  2   funded_amnt_inv             466285 non-null  float64
#  3   term                        466285 non-null  object
#  4   int_rate                    466285 non-null  float64
#  5   installment                 466285 non-null  float64
#  6   grade                       466285 non-null  object
#  7   emp_length                  445277 non-null  object
#  8   home_ownership              466285 non-null  object
#  9   annual_inc                  466281 non-null  float64
#  10  verification_status         466285 non-null  object
#  11  issue_d                     466285 non-null  object
#  12  loan_status                 466285 non-null  object
#  13  pymnt_plan                  466285 non-null  object
#  14  purpose                     466285 non-null  object
#  15  addr_state                  466285 non-null  object
#  16  dti                         466285 non-null  float64
#  17  delinq_2yrs                 466256 non-null  float64
#  18  earliest_cr_line            466256 non-null  object
#  19  inq_last_6mths              466256 non-null  float64
#  20  mths_since_last_delinq      215934 non-null  float64
#  21  open_acc                    466256 non-null  float64
#  22  pub_rec                     466256 non-null  float64
#  23  revol_bal                   466285 non-null  int64
#  24  revol_util                  465945 non-null  float64
#  25  total_acc                   466256 non-null  float64
#  26  initial_list_status         466285 non-null  object
#  27  out_prncp                   466285 non-null  float64
#  28  out_prncp_inv               466285 non-null  float64
#  29  total_pymnt                 466285 non-null  float64
#  30  total_pymnt_inv             466285 non-null  float64
#  31  total_rec_int               466285 non-null  float64
#  32  last_pymnt_d                465909 non-null  object
#  33  last_pymnt_amnt             466285 non-null  float64
#  34  last_credit_pull_d          466243 non-null  object
#  35  collections_12_mths_ex_med  466140 non-null  float64
#  36  policy_code                 466285 non-null  int64
#  37  acc_now_delinq              466256 non-null  float64
#  38  tot_coll_amt                396009 non-null  float64
#  39  tot_cur_bal                 396009 non-null  float64
#  40  total_rev_hi_lim            396009 non-null  float64
# dtypes: float64(23), int64(4), object(14)
# memory usage: 145.9+ MB

# %%
for col in new_data.columns :
  if new_data[col].dtype == "object" :
    unique = pd.unique(new_data[col])
    if len(unique) < 15 :
      print("column " + col + " has " +str(len(unique)) + " unique values and they are :\n " + str(unique))
    else :
      print(col + str(len(unique)) + " values")
# Out:
# column term has 2 unique values and they are :
#  [' 36 months' ' 60 months']
# column grade has 7 unique values and they are :
#  ['B' 'C' 'A' 'E' 'F' 'D' 'G']
# column emp_length has 12 unique values and they are :
#  ['10+ years' '< 1 year' '1 year' '3 years' '8 years' '9 years' '4 years'
#  '5 years' '6 years' '2 years' '7 years' nan]
# column home_ownership has 6 unique values and they are :
#  ['RENT' 'OWN' 'MORTGAGE' 'OTHER' 'NONE' 'ANY']
# column verification_status has 3 unique values and they are :
#  ['Verified' 'Source Verified' 'Not Verified']
# issue_d91 values
# column loan_status has 9 unique values and they are :
#  ['Fully Paid' 'Charged Off' 'Current' 'Default' 'Late (31-120 days)'
#  'In Grace Period' 'Late (16-30 days)'
#  'Does not meet the credit policy. Status:Fully Paid'
#  'Does not meet the credit policy. Status:Charged Off']
# column pymnt_plan has 2 unique values and they are :
#  ['n' 'y']
# column purpose has 14 unique values and they are :
#  ['credit_card' 'car' 'small_business' 'other' 'wedding'
#  'debt_consolidation' 'home_improvement' 'major_purchase' 'medical'
#  'moving' 'vacation' 'house' 'renewable_energy' 'educational']
# addr_state50 values
# earliest_cr_line665 values
# column initial_list_status has 2 unique values and they are :
#  ['f' 'w']
# last_pymnt_d99 values
# last_credit_pull_d104 values

# %% [markdown]
# #Creating target variable for prediction

# %%
new_data['loan_status'].value_counts(normalize = True)
# Out:
# Current                                                0.480878
# Fully Paid                                             0.396193
# Charged Off                                            0.091092
# Late (31-120 days)                                     0.014798
# In Grace Period                                        0.006747
# Does not meet the credit policy. Status:Fully Paid     0.004263
# Late (16-30 days)                                      0.002612
# Default                                                0.001784
# Does not meet the credit policy. Status:Charged Off    0.001632
# Name: loan_status, dtype: float64

# %% [markdown]
# $\text{Customers are not considered good for business if they have status as either: Late (31-120 days), Default , Does not meet the credit policy, Status:Charged Off ,Charged Off}$
# $\text{We encode such customers with 0 and others as 1 and make a new column of targets as good or bad customer.}$

# %%
new_data["good_bad"] = np.where(new_data.loc[:,'loan_status'].isin(['Charged Off' ,'Late (31-120 days)' ,'Default' , 'Does not meet the credit policy. Status:Charged Off']) , 0 , 1)

# %%
new_data.head(2)
# Out:
#    loan_amnt  funded_amnt  ...  total_rev_hi_lim good_bad
# 0       5000         5000  ...               NaN        1
# 1       2500         2500  ...               NaN        0
#
# [2 rows x 42 columns]

# %%
new_data.drop(columns = 'loan_status' , inplace =True , axis = 1)

# %%
new_data.head(2)
# Out:
#    loan_amnt  funded_amnt  ...  total_rev_hi_lim good_bad
# 0       5000         5000  ...               NaN        1
# 1       2500         2500  ...               NaN        0
#
# [2 rows x 41 columns]

# %% [markdown]
# #Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# $\text{Spliting data in 70:30 proportion resp. for training and testing.}$

# %%
# split data into 80/20 while keeping the distribution of bad loans in test set same as that in the pre-split dataset
X = new_data.drop('good_bad', axis = 1)
Y = new_data['good_bad']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 42, stratify = Y) #splitting data in 70:30 proportion for training : testing
X_train, X_test = X_train.copy(), X_test.copy()

# %%
print("shape of X_train : " , X_train.shape)
print("shape of X_test : " , X_test.shape)
print("shape of Y_train : " , Y_train.shape)
print("shape of Y_test : " , Y_test.shape)
# Out:
# shape of X_train :  (326399, 40)
# shape of X_test :  (139886, 40)
# shape of Y_train :  (326399,)
# shape of Y_test :  (139886,)

# %% [markdown]
# #Encoding Categorical variables

# %%
dummy = pd.DataFrame()
for col in X_train.columns :
  if X_train[col].dtype == "object" :
    #print(col)
    dummy[col] = X_train[col]
dummy.head(3)
# Out:
#               term grade  ... last_pymnt_d last_credit_pull_d
# 447765   36 months     C  ...       Oct-14             Jan-16
# 353201   36 months     C  ...       Dec-15             Jan-16
# 464366   36 months     A  ...       Apr-14             Jan-16
#
# [3 rows x 13 columns]

# %% [markdown]
# $\text{We have four columns containing date that can be encoded using number of months since today.term column has only 2 values and can be encoded as 0,1 or left as it is.}$ $\text{The emp_length column has 12 unique categorical values and can be encoded as below.}$

# %%
print(pd.unique(dummy.emp_length))
# Out:
# [nan '5 years' '10+ years' '3 years' '< 1 year' '6 years' '2 years'
#  '4 years' '8 years' '9 years' '7 years' '1 year']

# %% [markdown]
# $\text{So emp_length have 12 unique values of years.We can convert these values into numeric values indicating years instead of strings.}$$\text{ We will use pandas str.replace for converting these string to numeric.}$

# %%
#Handling string data
def emp_length2num(data , col) :
  """
  This function converts the string data into numerical data for columns ( here emp_length column) in dataframe

  """
  data[col] = data[col].str.replace('\+ years', '') #converting value 10+ years to 10
  data[col] = data[col].str.replace('< 1 year', str(0))
  data[col] = data[col].str.replace(' years', '') #converting values like 3 years/6 years/4 years/8 years ... etc to 3/6/4/8 respectively
  data[col] = data[col].str.replace(' year', '')
  data[col] = pd.to_numeric(data[col])
  data[col].fillna(value = 0 , inplace = True) #filling nan values with 0
  return data
  
#dqf = emp_length2num(dummy , 'emp_length')
#print(pd.unique(dqf.emp_length))

# %%
def convert_date2months(data , col) :
  """
  This function will convert the dates in column to number of months since day of running this code
  """
  from datetime import date
  today = pd.to_datetime(date.today()) #to get counts till date of today
  data[col] = pd.to_datetime(data[col] , format = '%b-%y') #convert date in columns to datetime
  data['months_since_' + col] = round(pd.to_numeric((today - data[col])/ np.timedelta64(1 , 'M'))) #Get months since todays date
  data['months_since_' + col] = data['months_since_' + col].apply(lambda x: data['months_since_' + col].max() if x < 0 else x) #removing any date that may have negative values due to misiing values
  data.drop(columns = [col] , inplace = True) #removing the column after getting the number of months since todays date
  return data

# %%
#The column term have only 2 unique values and they are in form of month in type string
#converting them to numeric 
def convert_term(data , col) :
  """
  The column term have only 2 unique values and they are in form of month in type string , converting them to numeric 
  """
  data[col] = data[col].str.replace(' months','')
  return data

# %%
dummy.head(2)
# Out:
#               term grade  ... last_pymnt_d last_credit_pull_d
# 447765   36 months     C  ...       Oct-14             Jan-16
# 353201   36 months     C  ...       Dec-15             Jan-16
#
# [2 rows x 13 columns]

# %%
X_train = convert_term(X_train , 'term')
X_train = convert_date2months(X_train , 'issue_d')
X_train = convert_date2months(X_train , 'earliest_cr_line' )
X_train = convert_date2months(X_train , 'last_pymnt_d' )
X_train = convert_date2months(X_train , 'last_credit_pull_d')
X_train = emp_length2num(X_train , 'emp_length')

# %%
X_train.head()
# Out:
#         loan_amnt  ...  months_since_last_credit_pull_d
# 447765       7975  ...                             67.0
# 353201      24000  ...                             67.0
# 464366      15000  ...                             67.0
# 371319      35000  ...                             67.0
# 119920      12000  ...                             67.0
#
# [5 rows x 40 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 326399 entries, 447765 to 38736
# Data columns (total 40 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   loan_amnt                        326399 non-null  int64
#  1   funded_amnt                      326399 non-null  int64
#  2   funded_amnt_inv                  326399 non-null  float64
#  3   term                             326399 non-null  object
#  4   int_rate                         326399 non-null  float64
#  5   installment                      326399 non-null  float64
#  6   grade                            326399 non-null  object
#  7   emp_length                       326399 non-null  float64
#  8   home_ownership                   326399 non-null  object
#  9   annual_inc                       326395 non-null  float64
#  10  verification_status              326399 non-null  object
#  11  pymnt_plan                       326399 non-null  object
#  12  purpose                          326399 non-null  object
#  13  addr_state                       326399 non-null  object
#  14  dti                              326399 non-null  float64
#  15  delinq_2yrs                      326374 non-null  float64
#  16  inq_last_6mths                   326374 non-null  float64
#  17  mths_since_last_delinq           151089 non-null  float64
#  18  open_acc                         326374 non-null  float64
#  19  pub_rec                          326374 non-null  float64
#  20  revol_bal                        326399 non-null  int64
#  21  revol_util                       326164 non-null  float64
#  22  total_acc                        326374 non-null  float64
#  23  initial_list_status              326399 non-null  object
#  24  out_prncp                        326399 non-null  float64
#  25  out_prncp_inv                    326399 non-null  float64
#  26  total_pymnt                      326399 non-null  float64
#  27  total_pymnt_inv                  326399 non-null  float64
#  28  total_rec_int                    326399 non-null  float64
#  29  last_pymnt_amnt                  326399 non-null  float64
#  30  collections_12_mths_ex_med       326293 non-null  float64
#  31  policy_code                      326399 non-null  int64
#  32  acc_now_delinq                   326374 non-null  float64
#  33  tot_coll_amt                     277203 non-null  float64
#  34  tot_cur_bal                      277203 non-null  float64
#  35  total_rev_hi_lim                 277203 non-null  float64
#  36  months_since_issue_d             326399 non-null  float64
#  37  months_since_earliest_cr_line    326374 non-null  float64
#  38  months_since_last_pymnt_d        326124 non-null  float64
#  39  months_since_last_credit_pull_d  326371 non-null  float64
# dtypes: float64(28), int64(4), object(8)
# memory usage: 102.1+ MB

# %%
for col in X_train.columns :
  if X_train[col].dtype == "object" :
    unique = pd.unique(X_train[col])
    if 2 < len(unique) < 15 :
      print("column " + col + " has " +str(len(unique)) + " unique values and they are :\n " + str(unique))
    else :
      print(col + ' has ' + str(len(unique)) + " values")
# Out:
# term has 2 values
# column grade has 7 unique values and they are :
#  ['C' 'A' 'E' 'B' 'D' 'F' 'G']
# column home_ownership has 5 unique values and they are :
#  ['OWN' 'MORTGAGE' 'RENT' 'OTHER' 'NONE']
# column verification_status has 3 unique values and they are :
#  ['Verified' 'Not Verified' 'Source Verified']
# pymnt_plan has 2 values
# column purpose has 14 unique values and they are :
#  ['debt_consolidation' 'credit_card' 'home_improvement' 'other' 'car'
#  'small_business' 'major_purchase' 'medical' 'wedding' 'house' 'moving'
#  'vacation' 'educational' 'renewable_energy']
# addr_state has 50 values
# initial_list_status has 2 values

# %%
X_train.describe()
# Out:
#            loan_amnt  ...  months_since_last_credit_pull_d
# count  326399.000000  ...                    326371.000000
# mean    14318.758176  ...                        71.211410
# std      8288.171665  ...                         9.760075
# min       500.000000  ...                        67.000000
# 25%      8000.000000  ...                        67.000000
# 50%     12000.000000  ...                        67.000000
# 75%     20000.000000  ...                        69.000000
# max     35000.000000  ...                       172.000000
#
# [8 rows x 32 columns]

# %% [markdown]
# #Feature Selection using chi-square and ANOVA

# %% [markdown]
# $\text{We will perform chi-squared test for categorical features and ANOVA F-statistic for numeric features, For selecting most suitable features from the datasets}$

# %% [markdown]
# $\text{For performing the above mention tests on data we will separate the categorical features from numeric features.}$

# %%
X_train_obj = X_train.select_dtypes(include= 'object').copy() #creating copy so that original data is not harmed
X_train_num = X_train.select_dtypes(include='number').copy() #creating copy so that original data is not harmed

# %%
from sklearn.feature_selection import f_classif #to perform ANOVA F-statistic
from scipy.stats import chi2_contingency #to perform chi-square test

# %%
def chi_test(data) :
  """ Perform chi-square test for data """

  chi_test = {} #to store p value of each feature

  for col in X_train_obj.columns :
    chi2 , p , dos , exp_freq = chi2_contingency(pd.crosstab(Y_train , X_train_obj[col])) 
    #crosstab gives frequency table of given factors by cross tabulation
    #chi2_contingency returns 4 values i.e. chi2 : test statistic , p : p value of test , dof : degree of freedom , exp_freq : expected frequency
    chi_test.setdefault('feature',[]).append(col)
    chi_test.setdefault('p-value',[]).append(round(p,5))

    results = pd.DataFrame(data= chi_test)
    results.sort_values(by = ['p-value'] , ascending= True ,ignore_index = True , inplace=True)

  return results

# %%
def anova_statistic(data , label):
  """ perform ANOVA F-statistic for data """
  
  warnings.filterwarnings("ignore")

  #first we need to handle missing values , for simplicity we will replace missing value by mean value of the column
  data.fillna(data.mean() , inplace=True)

  f_stat , p = f_classif(data , label) #gives F-statistic and p-value for each feature ,when provided data and target label

  #creating ANOVA table for features , f_stat , p-value
  anova = {'Feature' : data.columns.values , 'F-score' : f_stat , 'p-value' : p.round(decimals=5)}

  results = pd.DataFrame(anova)
  results.sort_values(by = ['F-score'] , ascending=False,ignore_index = True , inplace = True)

  return results

# %%
chi_result = chi_test(X_train_obj)
print("results of chi-square test on categorical features")
display(chi_result)
# Out:
# results of chi-square test on categorical features
#                feature  p-value
# 0                 term  0.00000
# 1                grade  0.00000
# 2       home_ownership  0.00000
# 3  verification_status  0.00000
# 4              purpose  0.00000
# 5           addr_state  0.00000
# 6  initial_list_status  0.00000
# 7           pymnt_plan  0.00511

# %% [markdown]
# $\text{Low p value signifies great statistical significance and our features are statistically important.}$$\text{Here all categorical features seems important but for sake of reducing complexity , we will consider first 4 features and see how our model performs}$

# %%
anova_result = anova_statistic(X_train_num , Y_train)
print("results of ANOVA-F statistic on numeric features")
display(anova_result)
# Out:
# results of ANOVA-F statistic on numeric features
#                             Feature       F-score  p-value
# 0         months_since_last_pymnt_d  21051.964544  0.00000
# 1                   total_pymnt_inv  12884.495065  0.00000
# 2                       total_pymnt  12793.058134  0.00000
# 3                          int_rate  10103.915879  0.00000
# 4                   last_pymnt_amnt   9479.514404  0.00000
# 5                         out_prncp   8369.729943  0.00000
# 6                     out_prncp_inv   8368.244737  0.00000
# 7   months_since_last_credit_pull_d   6314.690902  0.00000
# 8              months_since_issue_d   2494.627411  0.00000
# 9                    inq_last_6mths   1721.268395  0.00000
# 10                       revol_util    847.975294  0.00000
# 11                              dti    747.042135  0.00000
# 12                       annual_inc    722.800616  0.00000
# 13                      tot_cur_bal    669.063686  0.00000
# 14    months_since_earliest_cr_line    365.323929  0.00000
# 15                 total_rev_hi_lim    301.442517  0.00000
# 16                    total_rec_int    221.379321  0.00000
# 17                        total_acc    170.613533  0.00000
# 18                       emp_length    134.494791  0.00000
# 19                        revol_bal     94.264293  0.00000
# 20                      installment     72.262081  0.00000
# 21                        loan_amnt     58.620314  0.00000
# 22                      funded_amnt     50.870524  0.00000
# 23                          pub_rec     38.263493  0.00000
# 24                  funded_amnt_inv     24.553278  0.00000
# 25                         open_acc     13.268143  0.00027
# 26       collections_12_mths_ex_med      3.383612  0.06585
# 27           mths_since_last_delinq      2.373318  0.12343
# 28                      delinq_2yrs      2.353097  0.12504
# 29                     tot_coll_amt      0.340216  0.55970
# 30                   acc_now_delinq      0.084629  0.77112
# 31                      policy_code           NaN      NaN

# %% [markdown]
# $\text{Large F value in ANOVA translates to high statstical significance and low p value indicate High statistical significance.}$
# $\text{Here we will keep first 19 features as they have high F value and low p value. Also we will look for correlation in these 19 features}$

# %%
#Lets look for pair-wise correlations for the numerical features
imp_feat = anova_result.iloc[:19,0].to_list()
corr = X_train_num[imp_feat].corr(method='spearman')
plt.figure(figsize=(12,12))
sns.heatmap(corr , annot=True)

# %% [markdown]
# $\text{As we can see out_prncp and out_prncp_inv has high correlation, similiarly total_pymnt_inv and total_pymnt has high correlation.}$$\text{ We can remove any one from each of the two groups.}$

# %%
#creating list of columns to drop
col_to_drop = anova_result.iloc[19:,0].to_list()
col_to_drop.extend(chi_result.iloc[4:,0].to_list())
col_to_drop.extend(['total_pymnt_inv' , 'out_prncp_inv'])
def drop_columns(data , col_list):
  """ This function drops columns in a col_list from given dataframe data """
  data.drop(columns=col_list , inplace=True)
drop_columns(X_train , col_to_drop)

# %%
X_train.head(5)
# Out:
#        term  ...  months_since_last_credit_pull_d
# 447765   36  ...                             67.0
# 353201   36  ...                             67.0
# 464366   36  ...                             67.0
# 371319   60  ...                             67.0
# 119920   36  ...                             67.0
#
# [5 rows x 21 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 326399 entries, 447765 to 38736
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   term                             326399 non-null  object
#  1   int_rate                         326399 non-null  float64
#  2   grade                            326399 non-null  object
#  3   emp_length                       326399 non-null  float64
#  4   home_ownership                   326399 non-null  object
#  5   annual_inc                       326395 non-null  float64
#  6   verification_status              326399 non-null  object
#  7   dti                              326399 non-null  float64
#  8   inq_last_6mths                   326374 non-null  float64
#  9   revol_util                       326164 non-null  float64
#  10  total_acc                        326374 non-null  float64
#  11  out_prncp                        326399 non-null  float64
#  12  total_pymnt                      326399 non-null  float64
#  13  total_rec_int                    326399 non-null  float64
#  14  last_pymnt_amnt                  326399 non-null  float64
#  15  tot_cur_bal                      277203 non-null  float64
#  16  total_rev_hi_lim                 277203 non-null  float64
#  17  months_since_issue_d             326399 non-null  float64
#  18  months_since_earliest_cr_line    326374 non-null  float64
#  19  months_since_last_pymnt_d        326124 non-null  float64
#  20  months_since_last_credit_pull_d  326371 non-null  float64
# dtypes: float64(17), object(4)
# memory usage: 54.8+ MB

# %% [markdown]
# $\text{We still have 3 columns with categorical variables like grade , verification_status , home_ownership.We will encode them using dummy variables.}$

# %%
X_train.columns
# Out:
# Index(['term', 'int_rate', 'grade', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'dti', 'inq_last_6mths',
#        'revol_util', 'total_acc', 'out_prncp', 'total_pymnt', 'total_rec_int',
#        'last_pymnt_amnt', 'tot_cur_bal', 'total_rev_hi_lim',
#        'months_since_issue_d', 'months_since_earliest_cr_line',
#        'months_since_last_pymnt_d', 'months_since_last_credit_pull_d'],
#       dtype='object')

# %% [markdown]
# ##Dummy encoding for categorical data

# %%
#function to create dummies
def create_dummy(data , column_list):
  """ create dummy encoding for given column in data """
  dummy_list = []
  for col in column_list :
    dummy_list.append(pd.get_dummies(data = data[col] , prefix = col , prefix_sep=":"))
  dummy_list = pd.concat(dummy_list, axis=1)
  data = pd.concat([data , dummy_list] , axis=1)
  return data

X_train = create_dummy(X_train , ['grade', 'home_ownership', 'verification_status'])

# %%
X_train
# Out:
#        term  ...  verification_status:Verified
# 447765   36  ...                             1
# 353201   36  ...                             1
# 464366   36  ...                             0
# 371319   60  ...                             0
# 119920   36  ...                             0
# ...     ...  ...                           ...
# 200367   36  ...                             0
# 370650   36  ...                             0
# 214819   36  ...                             0
# 27751    60  ...                             0
# 38736    36  ...                             0
#
# [326399 rows x 36 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 326399 entries, 447765 to 38736
# Data columns (total 36 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   term                                 326399 non-null  object
#  1   int_rate                             326399 non-null  float64
#  2   grade                                326399 non-null  object
#  3   emp_length                           326399 non-null  float64
#  4   home_ownership                       326399 non-null  object
#  5   annual_inc                           326395 non-null  float64
#  6   verification_status                  326399 non-null  object
#  7   dti                                  326399 non-null  float64
#  8   inq_last_6mths                       326374 non-null  float64
#  9   revol_util                           326164 non-null  float64
#  10  total_acc                            326374 non-null  float64
#  11  out_prncp                            326399 non-null  float64
#  12  total_pymnt                          326399 non-null  float64
#  13  total_rec_int                        326399 non-null  float64
#  14  last_pymnt_amnt                      326399 non-null  float64
#  15  tot_cur_bal                          277203 non-null  float64
#  16  total_rev_hi_lim                     277203 non-null  float64
#  17  months_since_issue_d                 326399 non-null  float64
#  18  months_since_earliest_cr_line        326374 non-null  float64
#  19  months_since_last_pymnt_d            326124 non-null  float64
#  20  months_since_last_credit_pull_d      326371 non-null  float64
#  21  grade:A                              326399 non-null  uint8
#  22  grade:B                              326399 non-null  uint8
#  23  grade:C                              326399 non-null  uint8
#  24  grade:D                              326399 non-null  uint8
#  25  grade:E                              326399 non-null  uint8
#  26  grade:F                              326399 non-null  uint8
#  27  grade:G                              326399 non-null  uint8
#  28  home_ownership:MORTGAGE              326399 non-null  uint8
#  29  home_ownership:NONE                  326399 non-null  uint8
#  30  home_ownership:OTHER                 326399 non-null  uint8
#  31  home_ownership:OWN                   326399 non-null  uint8
#  32  home_ownership:RENT                  326399 non-null  uint8
#  33  verification_status:Not Verified     326399 non-null  uint8
#  34  verification_status:Source Verified  326399 non-null  uint8
#  35  verification_status:Verified         326399 non-null  uint8
# dtypes: float64(17), object(4), uint8(15)
# memory usage: 59.5+ MB

# %% [markdown]
# $\Large \textbf{With this our training data is pre-processed and cleaned to train for model}$

# %% [markdown]
# $\text{Applying the same cleaning procedure on test data.}$

# %%
X_test = emp_length2num(X_test , 'emp_length')
X_test = convert_date2months(X_test , 'earliest_cr_line')
X_test = convert_date2months(X_test , 'last_credit_pull_d')
X_test = convert_date2months(X_test , 'issue_d')
X_test = convert_date2months(X_test , 'last_pymnt_d')
X_test = convert_term(X_test , 'term')
drop_columns(X_test , col_to_drop)
X_test = create_dummy(X_test , ['grade', 'home_ownership', 'verification_status'])

#ensuring all columns in train data are their in test data by re-indexing
X_test = X_test.reindex(labels= X_train.columns , axis = 1 , fill_value=0)

# %% [markdown]
# $\text{Now our data is ready storing the data for further processing}$

# %% [markdown]
# #Final pre-processed and cleaned data

# %%
X_train.to_csv('train_data.csv', index=False)
X_test.to_csv('test_data.csv',index=False)
Y_train.to_csv('train_label.csv', index=False)
Y_test.to_csv('test_label.csv',index=False)
